# %%
import tensorflow as tf
import nibabel as nib
import numpy as np
import os
from sklearn.preprocessing import LabelBinarizer
from tensorflow.keras.utils import to_categorical
from scipy.ndimage import zoom, rotate, shift
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.regularizers import l2
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import nibabel as nib
import numpy as np
from skimage.transform import resize
import os

# Directories
healthy_directory = "nd/healthy/"
schiz_directory = "nd/schizophrenia/"
he_directory = "resized/healthy/"
sz_directory = "resized/schizophrenia/"

def resize_data(data, new_shape):
    # Resize each slice independently
    resized_slices = np.zeros((data.shape[0], new_shape[0], new_shape[1]))
    for i in range(data.shape[0]):
        resized_slices[i, :, :] = resize(data[i, :, :], new_shape, mode='reflect', anti_aliasing=True)
    return resized_slices

def process_and_resize_directory(input_directory, output_directory, slice_start, slice_end, new_shape):
    if not os.path.exists(output_directory):
        os.makedirs(output_directory)

    print(f"Listing files in directory: {input_directory}")
    files = os.listdir(input_directory)
    print(f"Files found: {files}")

    files_processed = False  # Flag to check if any file was processed

    for filename in files:
        if filename.endswith('.nii'):
            file_path = os.path.join(input_directory, filename)
            try:
                print(f"Processing file: {file_path}")

                # Load the NIfTI file
                img = nib.load(file_path)
                data = img.get_fdata()  # Get the image data as a NumPy array

                print(f"Original data shape: {data.shape}")

                # Extract middle slices
                middle_slices = data[slice_start:slice_end, :, :]

                # Resize each slice
                resized_slices = resize_data(middle_slices, new_shape)

                # Save the resized data
                new_file_path = os.path.join(output_directory, f"resized_{filename}")
                new_img = nib.Nifti1Image(resized_slices, img.affine)
                nib.save(new_img, new_file_path)
                print(f"Resized and saved {filename} to {new_file_path}")

                files_processed = True
            except Exception as e:
                print(f"Error processing {filename}: {e}")

    if not files_processed:
        print(f"No files processed in directory: {input_directory}")

# Define the range of slices you want to extract
slice_start = 86
slice_end = 106  # Note that end is exclusive

# Define the new shape
new_shape = (128, 128)

# Process and resize both directories
process_and_resize_directory(healthy_directory, he_directory, slice_start, slice_end, new_shape)
process_and_resize_directory(schiz_directory, sz_directory, slice_start, slice_end, new_shape)
# Out:
# Listing files in directory: nd/healthy/
# Files found: ['sub-101_T1w.nii', 'sub-102_T1w.nii', 'sub-10_T1w.nii', 'sub-11_T1w.nii', 'sub-12_T1w.nii', 'sub-13_T1w.nii', 'sub-14_T1w.nii', 'sub-15_T1w.nii', 'sub-16_T1w.nii', 'sub-20_T1w.nii', 'sub-35_T1w.nii', 'sub-36_T1w.nii', 'sub-37_T1w.nii', 'sub-38_T1w.nii', 'sub-43_T1w.nii', 'sub-46_T1w.nii', 'sub-47_T1w.nii', 'sub-49_T1w.nii', 'sub-50_T1w.nii', 'sub-51_T1w.nii', 'sub-53_T1w.nii', 'sub-54_T1w.nii', 'sub-55_T1w.nii', 'sub-56_T1w.nii', 'sub-57_T1w.nii', 'sub-58_T1w.nii', 'sub-59_T1w.nii', 'sub-64_T1w.nii', 'sub-65_T1w.nii', 'sub-69_T1w.nii', 'sub-72_T1w.nii', 'sub-73_T1w.nii', 'sub-81_T1w.nii', 'sub-87_T1w.nii', 'sub-88_T1w.nii', 'sub-89_T1w.nii', 'sub-90_T1w.nii', 'sub-97_T1w.nii', 'sub-98_T1w.nii', 'sub-A00000300_ses-20110101_acq-mprage_run-01_T1w.nii', 'sub-A00002198_ses-20110101_acq-mprage_run-01_T1w.nii', 'sub-A00003150_ses-20110101_acq-mprage_run-01_T1w.nii', 'sub-A00004087_ses-20100101_acq-mprage_run-04_T1w.nii', 'sub-A00007409_ses-20110101_acq-mprage_run-01_T1w.nii', 'sub-A00009946_ses-20110101_acq-mprage_run-02_T1w.nii', 'sub-A00010150_ses-20110101_acq-mprage_run-01_T1w.nii', 'sub-A00010684_ses-20110101_acq-mprage_run-02_T1w.nii', 'sub-A00011265_ses-20110101_acq-mprage_run-02_T1w.nii', 'sub-A00011725_ses-20110101_acq-mprage_run-01_T1w.nii', 'sub-A00012995_ses-20110101_acq-mprage_run-02_T1w.nii', 'sub-A00013140_ses-20090101_acq-mprage_run-02_T1w.nii', 'sub-A00013363_ses-20110101_acq-mprage_run-02_T1w.nii', 'sub-A00013816_ses-20110101_acq-mprage_run-02_T1w.nii', 'sub-A00014120_ses-20110101_acq-mprage_run-02_T1w.nii', 'sub-A00014225_ses-20110101_acq-mprage_run-01_T1w.nii', 'sub-A00014522_ses-20100101_acq-mprage_run-02_T1w.nii', 'sub-A00014839_ses-20090101_acq-mprage_run-02_T1w.nii', 'sub-A00014898_ses-20090101_acq-mprage_run-02_T1w.nii', 'sub-A00015759_ses-20120101_acq-mprage_run-02_T1w.nii', 'sub-A00015826_ses-20110101_acq-mprage_run-01_T1w.nii', 'sub-A00017294_ses-20110101_acq-mprage_run-02_T1w.nii', 'sub-A00018335_ses-20090101_acq-mprage_run-01_T1w.nii', 'sub-A00018553_ses-20110101_acq-mprage_run-02_T1w.nii', 'sub-A00018716_ses-20090101_acq-mprage_run-02_T1w.nii', 'sub-A00019888_ses-20110101_acq-mprage_run-01_T1w.nii', 'sub-A00020805_ses-20100101_acq-mprage_run-01_T1w.nii', 'sub-A00020895_ses-20100101_acq-mprage_run-02_T1w.nii', 'sub-A00020968_ses-20100101_acq-mprage_run-02_T1w.nii', 'sub-A00020984_ses-20100101_acq-mprage_run-01_T1w.nii', 'sub-A00021058_ses-20100101_acq-mprage_run-01_T1w.nii', 'sub-A00021072_ses-20100101_acq-mprage_run-02_T1w.nii', 'sub-A00021081_ses-20100101_acq-mprage_run-01_T1w.nii', 'sub-A00021085_ses-20100101_acq-mprage_run-01_T1w.nii', 'sub-A00021145_ses-20100101_acq-mprage_run-02_T1w.nii', 'sub-A00022400_ses-20100101_acq-mprage_run-01_T1w.nii', 'sub-A00022490_ses-20090101_acq-mprage_run-02_T1w.nii', 'sub-A00022509_ses-20090101_acq-mprage_run-01_T1w.nii', 'sub-A00022592_ses-20110101_acq-mprage_run-02_T1w.nii', 'sub-A00022619_ses-20090101_acq-mprage_run-02_T1w.nii', 'sub-A00022653_ses-20090101_acq-mprage_run-02_T1w.nii', 'sub-A00022687_ses-20090101_acq-mprage_run-02_T1w.nii', 'sub-A00022727_ses-20090101_acq-mprage_run-02_T1w.nii', 'sub-A00022729_ses-20090101_acq-mprage_run-01_T1w.nii', 'sub-A00022773_ses-20090101_acq-mprage_run-01_T1w.nii', 'sub-A00022810_ses-20090101_acq-mprage_run-02_T1w.nii', 'sub-A00022835_ses-20090101_acq-mprage_run-01_T1w.nii', 'sub-A00022837_ses-20090101_acq-mprage_run-01_T1w.nii', 'sub-A00022915_ses-20090101_acq-mprage_run-01_T1w.nii', 'sub-A00023095_ses-20090101_acq-mprage_run-01_T1w.nii', 'sub-A00023120_ses-20090101_acq-mprage_run-02_T1w.nii', 'sub-A00023131_ses-20110101_acq-mprage_run-02_T1w.nii', 'sub-A00023143_ses-20090101_acq-mprage_run-01_T1w.nii', 'sub-A00023330_ses-20090101_acq-mprage_run-01_T1w.nii', 'sub-A00023337_ses-20100101_acq-mprage_run-01_T1w.nii', 'sub-A00023730_ses-20120101_acq-mprage_run-01_T1w.nii', 'sub-A00023800_ses-20090101_acq-mprage_run-02_T1w.nii', 'sub-A00023848_ses-20090101_acq-mprage_run-01_T1w.nii', 'sub-A00023866_ses-20090101_acq-mp ...
# Processing file: nd/healthy/sub-101_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-101_T1w.nii to resized/healthy/resized_sub-101_T1w.nii
# Processing file: nd/healthy/sub-102_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-102_T1w.nii to resized/healthy/resized_sub-102_T1w.nii
# Processing file: nd/healthy/sub-10_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-10_T1w.nii to resized/healthy/resized_sub-10_T1w.nii
# Processing file: nd/healthy/sub-11_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-11_T1w.nii to resized/healthy/resized_sub-11_T1w.nii
# Processing file: nd/healthy/sub-12_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-12_T1w.nii to resized/healthy/resized_sub-12_T1w.nii
# Processing file: nd/healthy/sub-13_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-13_T1w.nii to resized/healthy/resized_sub-13_T1w.nii
# Processing file: nd/healthy/sub-14_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-14_T1w.nii to resized/healthy/resized_sub-14_T1w.nii
# Processing file: nd/healthy/sub-15_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-15_T1w.nii to resized/healthy/resized_sub-15_T1w.nii
# Processing file: nd/healthy/sub-16_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-16_T1w.nii to resized/healthy/resized_sub-16_T1w.nii
# Processing file: nd/healthy/sub-20_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-20_T1w.nii to resized/healthy/resized_sub-20_T1w.nii
# Processing file: nd/healthy/sub-35_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-35_T1w.nii to resized/healthy/resized_sub-35_T1w.nii
# Processing file: nd/healthy/sub-36_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-36_T1w.nii to resized/healthy/resized_sub-36_T1w.nii
# Processing file: nd/healthy/sub-37_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-37_T1w.nii to resized/healthy/resized_sub-37_T1w.nii
# Processing file: nd/healthy/sub-38_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-38_T1w.nii to resized/healthy/resized_sub-38_T1w.nii
# Processing file: nd/healthy/sub-43_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-43_T1w.nii to resized/healthy/resized_sub-43_T1w.nii
# Processing file: nd/healthy/sub-46_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-46_T1w.nii to resized/healthy/resized_sub-46_T1w.nii
# Processing file: nd/healthy/sub-47_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-47_T1w.nii to resized/healthy/resized_sub-47_T1w.nii
# Processing file: nd/healthy/sub-49_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-49_T1w.nii to resized/healthy/resized_sub-49_T1w.nii
# Processing file: nd/healthy/sub-50_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-50_T1w.nii to resized/healthy/resized_sub-50_T1w.nii
# Processing file: nd/healthy/sub-51_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-51_T1w.nii to resized/healthy/resized_sub-51_T1w.nii
# Processing file: nd/healthy/sub-53_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-53_T1w.nii to resized/healthy/resized_sub-53_T1w.nii
# Processing file: nd/healthy/sub-54_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-54_T1w.nii to resized/healthy/resized_sub-54_T1w.nii
# Processing file: nd/healthy/sub-55_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-55_T1w.nii to resized/healthy/resized_sub-55_T1w.nii
# Processing file: nd/healthy/sub-56_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-56_T1w.nii to resized/healthy/resized_sub-56_T1w.nii
# Processing file: nd/healthy/sub-57_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-57_T1w.nii to resized/healthy/resized_sub-57_T1w.nii
# Processing file: nd/healthy/sub-58_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-58_T1w.nii to resized/healthy/resized_sub-58_T1w.nii
# Processing file: nd/healthy/sub-59_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-59_T1w.nii to resized/healthy/resized_sub-59_T1w.nii
# Processing file: nd/healthy/sub-64_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-64_T1w.nii to resized/healthy/resized_sub-64_T1w.nii
# Processing file: nd/healthy/sub-65_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-65_T1w.nii to resized/healthy/resized_sub-65_T1w.nii
# Processing file: nd/healthy/sub-69_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-69_T1w.nii to resized/healthy/resized_sub-69_T1w.nii
# Processing file: nd/healthy/sub-72_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-72_T1w.nii to resized/healthy/resized_sub-72_T1w.nii
# Processing file: nd/healthy/sub-73_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-73_T1w.nii to resized/healthy/resized_sub-73_T1w.nii
# Processing file: nd/healthy/sub-81_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-81_T1w.nii to resized/healthy/resized_sub-81_T1w.nii
# Processing file: nd/healthy/sub-87_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-87_T1w.nii to resized/healthy/resized_sub-87_T1w.nii
# Processing file: nd/healthy/sub-88_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-88_T1w.nii to resized/healthy/resized_sub-88_T1w.nii
# Processing file: nd/healthy/sub-89_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-89_T1w.nii to resized/healthy/resized_sub-89_T1w.nii
# Processing file: nd/healthy/sub-90_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-90_T1w.nii to resized/healthy/resized_sub-90_T1w.nii
# Processing file: nd/healthy/sub-97_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-97_T1w.nii to resized/healthy/resized_sub-97_T1w.nii
# Processing file: nd/healthy/sub-98_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-98_T1w.nii to resized/healthy/resized_sub-98_T1w.nii
# Processing file: nd/healthy/sub-A00000300_ses-20110101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00000300_ses-20110101_acq-mprage_run-01_T1w.nii to resized/healthy/resized_sub-A00000300_ses-20110101_acq-mprage_run-01_T1w.nii
# Processing file: nd/healthy/sub-A00002198_ses-20110101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00002198_ses-20110101_acq-mprage_run-01_T1w.nii to resized/healthy/resized_sub-A00002198_ses-20110101_acq-mprage_run-01_T1w.nii
# Processing file: nd/healthy/sub-A00003150_ses-20110101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00003150_ses-20110101_acq-mprage_run-01_T1w.nii to resized/healthy/resized_sub-A00003150_ses-20110101_acq-mprage_run-01_T1w.nii
# Processing file: nd/healthy/sub-A00004087_ses-20100101_acq-mprage_run-04_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00004087_ses-20100101_acq-mprage_run-04_T1w.nii to resized/healthy/resized_sub-A00004087_ses-20100101_acq-mprage_run-04_T1w.nii
# Processing file: nd/healthy/sub-A00007409_ses-20110101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00007409_ses-20110101_acq-mprage_run-01_T1w.nii to resized/healthy/resized_sub-A00007409_ses-20110101_acq-mprage_run-01_T1w.nii
# Processing file: nd/healthy/sub-A00009946_ses-20110101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00009946_ses-20110101_acq-mprage_run-02_T1w.nii to resized/healthy/resized_sub-A00009946_ses-20110101_acq-mprage_run-02_T1w.nii
# Processing file: nd/healthy/sub-A00010150_ses-20110101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00010150_ses-20110101_acq-mprage_run-01_T1w.nii to resized/healthy/resized_sub-A00010150_ses-20110101_acq-mprage_run-01_T1w.nii
# Processing file: nd/healthy/sub-A00010684_ses-20110101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00010684_ses-20110101_acq-mprage_run-02_T1w.nii to resized/healthy/resized_sub-A00010684_ses-20110101_acq-mprage_run-02_T1w.nii
# Processing file: nd/healthy/sub-A00011265_ses-20110101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00011265_ses-20110101_acq-mprage_run-02_T1w.nii to resized/healthy/resized_sub-A00011265_ses-20110101_acq-mprage_run-02_T1w.nii
# Processing file: nd/healthy/sub-A00011725_ses-20110101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00011725_ses-20110101_acq-mprage_run-01_T1w.nii to resized/healthy/resized_sub-A00011725_ses-20110101_acq-mprage_run-01_T1w.nii
# Processing file: nd/healthy/sub-A00012995_ses-20110101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00012995_ses-20110101_acq-mprage_run-02_T1w.nii to resized/healthy/resized_sub-A00012995_ses-20110101_acq-mprage_run-02_T1w.nii
# Processing file: nd/healthy/sub-A00013140_ses-20090101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00013140_ses-20090101_acq-mprage_run-02_T1w.nii to resized/healthy/resized_sub-A00013140_ses-20090101_acq-mprage_run-02_T1w.nii
# Processing file: nd/healthy/sub-A00013363_ses-20110101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00013363_ses-20110101_acq-mprage_run-02_T1w.nii to resized/healthy/resized_sub-A00013363_ses-20110101_acq-mprage_run-02_T1w.nii
# Processing file: nd/healthy/sub-A00013816_ses-20110101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00013816_ses-20110101_acq-mprage_run-02_T1w.nii to resized/healthy/resized_sub-A00013816_ses-20110101_acq-mprage_run-02_T1w.nii
# Processing file: nd/healthy/sub-A00014120_ses-20110101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00014120_ses-20110101_acq-mprage_run-02_T1w.nii to resized/healthy/resized_sub-A00014120_ses-20110101_acq-mprage_run-02_T1w.nii
# Processing file: nd/healthy/sub-A00014225_ses-20110101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00014225_ses-20110101_acq-mprage_run-01_T1w.nii to resized/healthy/resized_sub-A00014225_ses-20110101_acq-mprage_run-01_T1w.nii
# Processing file: nd/healthy/sub-A00014522_ses-20100101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00014522_ses-20100101_acq-mprage_run-02_T1w.nii to resized/healthy/resized_sub-A00014522_ses-20100101_acq-mprage_run-02_T1w.nii
# Processing file: nd/healthy/sub-A00014839_ses-20090101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00014839_ses-20090101_acq-mprage_run-02_T1w.nii to resized/healthy/resized_sub-A00014839_ses-20090101_acq-mprage_run-02_T1w.nii
# Processing file: nd/healthy/sub-A00014898_ses-20090101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00014898_ses-20090101_acq-mprage_run-02_T1w.nii to resized/healthy/resized_sub-A00014898_ses-20090101_acq-mprage_run-02_T1w.nii
# Processing file: nd/healthy/sub-A00015759_ses-20120101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00015759_ses-20120101_acq-mprage_run-02_T1w.nii to resized/healthy/resized_sub-A00015759_ses-20120101_acq-mprage_run-02_T1w.nii
# Processing file: nd/healthy/sub-A00015826_ses-20110101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00015826_ses-20110101_acq-mprage_run-01_T1w.nii to resized/healthy/resized_sub-A00015826_ses-20110101_acq-mprage_run-01_T1w.nii
# Processing file: nd/healthy/sub-A00017294_ses-20110101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00017294_ses-20110101_acq-mprage_run-02_T1w.nii to resized/healthy/resized_sub-A00017294_ses-20110101_acq-mprage_run-02_T1w.nii
# Processing file: nd/healthy/sub-A00018335_ses-20090101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00018335_ses-20090101_acq-mprage_run-01_T1w.nii to resized/healthy/resized_sub-A00018335_ses-20090101_acq-mprage_run-01_T1w.nii
# Processing file: nd/healthy/sub-A00018553_ses-20110101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00018553_ses-20110101_acq-mprage_run-02_T1w.nii to resized/healthy/resized_sub-A00018553_ses-20110101_acq-mprage_run-02_T1w.nii
# Processing file: nd/healthy/sub-A00018716_ses-20090101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00018716_ses-20090101_acq-mprage_run-02_T1w.nii to resized/healthy/resized_sub-A00018716_ses-20090101_acq-mprage_run-02_T1w.nii
# Processing file: nd/healthy/sub-A00019888_ses-20110101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00019888_ses-20110101_acq-mprage_run-01_T1w.nii to resized/healthy/resized_sub-A00019888_ses-20110101_acq-mprage_run-01_T1w.nii
# Processing file: nd/healthy/sub-A00020805_ses-20100101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00020805_ses-20100101_acq-mprage_run-01_T1w.nii to resized/healthy/resized_sub-A00020805_ses-20100101_acq-mprage_run-01_T1w.nii
# Processing file: nd/healthy/sub-A00020895_ses-20100101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00020895_ses-20100101_acq-mprage_run-02_T1w.nii to resized/healthy/resized_sub-A00020895_ses-20100101_acq-mprage_run-02_T1w.nii
# Processing file: nd/healthy/sub-A00020968_ses-20100101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00020968_ses-20100101_acq-mprage_run-02_T1w.nii to resized/healthy/resized_sub-A00020968_ses-20100101_acq-mprage_run-02_T1w.nii
# Processing file: nd/healthy/sub-A00020984_ses-20100101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00020984_ses-20100101_acq-mprage_run-01_T1w.nii to resized/healthy/resized_sub-A00020984_ses-20100101_acq-mprage_run-01_T1w.nii
# Processing file: nd/healthy/sub-A00021058_ses-20100101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00021058_ses-20100101_acq-mprage_run-01_T1w.nii to resized/healthy/resized_sub-A00021058_ses-20100101_acq-mprage_run-01_T1w.nii
# Processing file: nd/healthy/sub-A00021072_ses-20100101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00021072_ses-20100101_acq-mprage_run-02_T1w.nii to resized/healthy/resized_sub-A00021072_ses-20100101_acq-mprage_run-02_T1w.nii
# Processing file: nd/healthy/sub-A00021081_ses-20100101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00021081_ses-20100101_acq-mprage_run-01_T1w.nii to resized/healthy/resized_sub-A00021081_ses-20100101_acq-mprage_run-01_T1w.nii
# Processing file: nd/healthy/sub-A00021085_ses-20100101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00021085_ses-20100101_acq-mprage_run-01_T1w.nii to resized/healthy/resized_sub-A00021085_ses-20100101_acq-mprage_run-01_T1w.nii
# Processing file: nd/healthy/sub-A00021145_ses-20100101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00021145_ses-20100101_acq-mprage_run-02_T1w.nii to resized/healthy/resized_sub-A00021145_ses-20100101_acq-mprage_run-02_T1w.nii
# Processing file: nd/healthy/sub-A00022400_ses-20100101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00022400_ses-20100101_acq-mprage_run-01_T1w.nii to resized/healthy/resized_sub-A00022400_ses-20100101_acq-mprage_run-01_T1w.nii
# Processing file: nd/healthy/sub-A00022490_ses-20090101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00022490_ses-20090101_acq-mprage_run-02_T1w.nii to resized/healthy/resized_sub-A00022490_ses-20090101_acq-mprage_run-02_T1w.nii
# Processing file: nd/healthy/sub-A00022509_ses-20090101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00022509_ses-20090101_acq-mprage_run-01_T1w.nii to resized/healthy/resized_sub-A00022509_ses-20090101_acq-mprage_run-01_T1w.nii
# Processing file: nd/healthy/sub-A00022592_ses-20110101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00022592_ses-20110101_acq-mprage_run-02_T1w.nii to resized/healthy/resized_sub-A00022592_ses-20110101_acq-mprage_run-02_T1w.nii
# Processing file: nd/healthy/sub-A00022619_ses-20090101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00022619_ses-20090101_acq-mprage_run-02_T1w.nii to resized/healthy/resized_sub-A00022619_ses-20090101_acq-mprage_run-02_T1w.nii
# Processing file: nd/healthy/sub-A00022653_ses-20090101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00022653_ses-20090101_acq-mprage_run-02_T1w.nii to resized/healthy/resized_sub-A00022653_ses-20090101_acq-mprage_run-02_T1w.nii
# Processing file: nd/healthy/sub-A00022687_ses-20090101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00022687_ses-20090101_acq-mprage_run-02_T1w.nii to resized/healthy/resized_sub-A00022687_ses-20090101_acq-mprage_run-02_T1w.nii
# Processing file: nd/healthy/sub-A00022727_ses-20090101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00022727_ses-20090101_acq-mprage_run-02_T1w.nii to resized/healthy/resized_sub-A00022727_ses-20090101_acq-mprage_run-02_T1w.nii
# Processing file: nd/healthy/sub-A00022729_ses-20090101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00022729_ses-20090101_acq-mprage_run-01_T1w.nii to resized/healthy/resized_sub-A00022729_ses-20090101_acq-mprage_run-01_T1w.nii
# Processing file: nd/healthy/sub-A00022773_ses-20090101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00022773_ses-20090101_acq-mprage_run-01_T1w.nii to resized/healthy/resized_sub-A00022773_ses-20090101_acq-mprage_run-01_T1w.nii
# Processing file: nd/healthy/sub-A00022810_ses-20090101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00022810_ses-20090101_acq-mprage_run-02_T1w.nii to resized/healthy/resized_sub-A00022810_ses-20090101_acq-mprage_run-02_T1w.nii
# Processing file: nd/healthy/sub-A00022835_ses-20090101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00022835_ses-20090101_acq-mprage_run-01_T1w.nii to resized/healthy/resized_sub-A00022835_ses-20090101_acq-mprage_run-01_T1w.nii
# Processing file: nd/healthy/sub-A00022837_ses-20090101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00022837_ses-20090101_acq-mprage_run-01_T1w.nii to resized/healthy/resized_sub-A00022837_ses-20090101_acq-mprage_run-01_T1w.nii
# Processing file: nd/healthy/sub-A00022915_ses-20090101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00022915_ses-20090101_acq-mprage_run-01_T1w.nii to resized/healthy/resized_sub-A00022915_ses-20090101_acq-mprage_run-01_T1w.nii
# Processing file: nd/healthy/sub-A00023095_ses-20090101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00023095_ses-20090101_acq-mprage_run-01_T1w.nii to resized/healthy/resized_sub-A00023095_ses-20090101_acq-mprage_run-01_T1w.nii
# Processing file: nd/healthy/sub-A00023120_ses-20090101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00023120_ses-20090101_acq-mprage_run-02_T1w.nii to resized/healthy/resized_sub-A00023120_ses-20090101_acq-mprage_run-02_T1w.nii
# Processing file: nd/healthy/sub-A00023131_ses-20110101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00023131_ses-20110101_acq-mprage_run-02_T1w.nii to resized/healthy/resized_sub-A00023131_ses-20110101_acq-mprage_run-02_T1w.nii
# Processing file: nd/healthy/sub-A00023143_ses-20090101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00023143_ses-20090101_acq-mprage_run-01_T1w.nii to resized/healthy/resized_sub-A00023143_ses-20090101_acq-mprage_run-01_T1w.nii
# Processing file: nd/healthy/sub-A00023330_ses-20090101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00023330_ses-20090101_acq-mprage_run-01_T1w.nii to resized/healthy/resized_sub-A00023330_ses-20090101_acq-mprage_run-01_T1w.nii
# Processing file: nd/healthy/sub-A00023337_ses-20100101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00023337_ses-20100101_acq-mprage_run-01_T1w.nii to resized/healthy/resized_sub-A00023337_ses-20100101_acq-mprage_run-01_T1w.nii
# Processing file: nd/healthy/sub-A00023730_ses-20120101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00023730_ses-20120101_acq-mprage_run-01_T1w.nii to resized/healthy/resized_sub-A00023730_ses-20120101_acq-mprage_run-01_T1w.nii
# Processing file: nd/healthy/sub-A00023800_ses-20090101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00023800_ses-20090101_acq-mprage_run-02_T1w.nii to resized/healthy/resized_sub-A00023800_ses-20090101_acq-mprage_run-02_T1w.nii
# Processing file: nd/healthy/sub-A00023848_ses-20090101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00023848_ses-20090101_acq-mprage_run-01_T1w.nii to resized/healthy/resized_sub-A00023848_ses-20090101_acq-mprage_run-01_T1w.nii
# Processing file: nd/healthy/sub-A00023866_ses-20090101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00023866_ses-20090101_acq-mprage_run-02_T1w.nii to resized/healthy/resized_sub-A00023866_ses-20090101_acq-mprage_run-02_T1w.nii
# Processing file: nd/healthy/sub-A00024160_ses-20090101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00024160_ses-20090101_acq-mprage_run-02_T1w.nii to resized/healthy/resized_sub-A00024160_ses-20090101_acq-mprage_run-02_T1w.nii
# Processing file: nd/healthy/sub-A00024301_ses-20090101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00024301_ses-20090101_acq-mprage_run-02_T1w.nii to resized/healthy/resized_sub-A00024301_ses-20090101_acq-mprage_run-02_T1w.nii
# Processing file: nd/healthy/sub-A00024372_ses-20090101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00024372_ses-20090101_acq-mprage_run-01_T1w.nii to resized/healthy/resized_sub-A00024372_ses-20090101_acq-mprage_run-01_T1w.nii
# Processing file: nd/healthy/sub-A00024446_ses-20090101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00024446_ses-20090101_acq-mprage_run-01_T1w.nii to resized/healthy/resized_sub-A00024446_ses-20090101_acq-mprage_run-01_T1w.nii
# Processing file: nd/healthy/sub-A00024535_ses-20090101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00024535_ses-20090101_acq-mprage_run-02_T1w.nii to resized/healthy/resized_sub-A00024535_ses-20090101_acq-mprage_run-02_T1w.nii
# Processing file: nd/healthy/sub-A00024546_ses-20090101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00024546_ses-20090101_acq-mprage_run-02_T1w.nii to resized/healthy/resized_sub-A00024546_ses-20090101_acq-mprage_run-02_T1w.nii
# Processing file: nd/healthy/sub-A00024663_ses-20090101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00024663_ses-20090101_acq-mprage_run-01_T1w.nii to resized/healthy/resized_sub-A00024663_ses-20090101_acq-mprage_run-01_T1w.nii
# Processing file: nd/healthy/sub-A00024820_ses-20090101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00024820_ses-20090101_acq-mprage_run-01_T1w.nii to resized/healthy/resized_sub-A00024820_ses-20090101_acq-mprage_run-01_T1w.nii
# Processing file: nd/healthy/sub-A00024932_ses-20090101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00024932_ses-20090101_acq-mprage_run-02_T1w.nii to resized/healthy/resized_sub-A00024932_ses-20090101_acq-mprage_run-02_T1w.nii
# Processing file: nd/healthy/sub-A00024955_ses-20090101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00024955_ses-20090101_acq-mprage_run-01_T1w.nii to resized/healthy/resized_sub-A00024955_ses-20090101_acq-mprage_run-01_T1w.nii
# Processing file: nd/healthy/sub-A00025969_ses-20090101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00025969_ses-20090101_acq-mprage_run-02_T1w.nii to resized/healthy/resized_sub-A00025969_ses-20090101_acq-mprage_run-02_T1w.nii
# Processing file: nd/healthy/sub-A00026907_ses-20100101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00026907_ses-20100101_acq-mprage_run-02_T1w.nii to resized/healthy/resized_sub-A00026907_ses-20100101_acq-mprage_run-02_T1w.nii
# Processing file: nd/healthy/sub-A00026945_ses-20100101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00026945_ses-20100101_acq-mprage_run-02_T1w.nii to resized/healthy/resized_sub-A00026945_ses-20100101_acq-mprage_run-02_T1w.nii
# Processing file: nd/healthy/sub-A00027487_ses-20120101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00027487_ses-20120101_acq-mprage_run-01_T1w.nii to resized/healthy/resized_sub-A00027487_ses-20120101_acq-mprage_run-01_T1w.nii
# Processing file: nd/healthy/sub-A00027787_ses-20110101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00027787_ses-20110101_acq-mprage_run-01_T1w.nii to resized/healthy/resized_sub-A00027787_ses-20110101_acq-mprage_run-01_T1w.nii
# Processing file: nd/healthy/sub-A00028052_ses-20110101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00028052_ses-20110101_acq-mprage_run-01_T1w.nii to resized/healthy/resized_sub-A00028052_ses-20110101_acq-mprage_run-01_T1w.nii
# Processing file: nd/healthy/sub-A00028406_ses-20120101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00028406_ses-20120101_acq-mprage_run-02_T1w.nii to resized/healthy/resized_sub-A00028406_ses-20120101_acq-mprage_run-02_T1w.nii
# Processing file: nd/healthy/sub-A00028409_ses-20120101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00028409_ses-20120101_acq-mprage_run-02_T1w.nii to resized/healthy/resized_sub-A00028409_ses-20120101_acq-mprage_run-02_T1w.nii
# Processing file: nd/healthy/sub-A00029226_ses-20120101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00029226_ses-20120101_acq-mprage_run-01_T1w.nii to resized/healthy/resized_sub-A00029226_ses-20120101_acq-mprage_run-01_T1w.nii
# Processing file: nd/healthy/sub-A00029452_ses-20120101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00029452_ses-20120101_acq-mprage_run-02_T1w.nii to resized/healthy/resized_sub-A00029452_ses-20120101_acq-mprage_run-02_T1w.nii
# Processing file: nd/healthy/sub-A00031478_ses-20120101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00031478_ses-20120101_acq-mprage_run-01_T1w.nii to resized/healthy/resized_sub-A00031478_ses-20120101_acq-mprage_run-01_T1w.nii
# Processing file: nd/healthy/sub-A00031764_ses-20120101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00031764_ses-20120101_acq-mprage_run-01_T1w.nii to resized/healthy/resized_sub-A00031764_ses-20120101_acq-mprage_run-01_T1w.nii
# Processing file: nd/healthy/sub-A00033214_ses-20120101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00033214_ses-20120101_acq-mprage_run-01_T1w.nii to resized/healthy/resized_sub-A00033214_ses-20120101_acq-mprage_run-01_T1w.nii
# Processing file: nd/healthy/sub-A00035751_ses-20130101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00035751_ses-20130101_acq-mprage_run-02_T1w.nii to resized/healthy/resized_sub-A00035751_ses-20130101_acq-mprage_run-02_T1w.nii
# Processing file: nd/healthy/sub-A00036049_ses-20130101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00036049_ses-20130101_acq-mprage_run-01_T1w.nii to resized/healthy/resized_sub-A00036049_ses-20130101_acq-mprage_run-01_T1w.nii
# Processing file: nd/healthy/sub-A00036555_ses-20130101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00036555_ses-20130101_acq-mprage_run-02_T1w.nii to resized/healthy/resized_sub-A00036555_ses-20130101_acq-mprage_run-02_T1w.nii
# Processing file: nd/healthy/sub-A00036844_ses-20130101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00036844_ses-20130101_acq-mprage_run-01_T1w.nii to resized/healthy/resized_sub-A00036844_ses-20130101_acq-mprage_run-01_T1w.nii
# Processing file: nd/healthy/sub-A00036897_ses-20130101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00036897_ses-20130101_acq-mprage_run-02_T1w.nii to resized/healthy/resized_sub-A00036897_ses-20130101_acq-mprage_run-02_T1w.nii
# Processing file: nd/healthy/sub-A00036916_ses-20130101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00036916_ses-20130101_acq-mprage_run-01_T1w.nii to resized/healthy/resized_sub-A00036916_ses-20130101_acq-mprage_run-01_T1w.nii
# Processing file: nd/healthy/sub-A00037007_ses-20130101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00037007_ses-20130101_acq-mprage_run-02_T1w.nii to resized/healthy/resized_sub-A00037007_ses-20130101_acq-mprage_run-02_T1w.nii
# Processing file: nd/healthy/sub-A00037238_ses-20130101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00037238_ses-20130101_acq-mprage_run-02_T1w.nii to resized/healthy/resized_sub-A00037238_ses-20130101_acq-mprage_run-02_T1w.nii
# Processing file: nd/healthy/sub-A00037318_ses-20130101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00037318_ses-20130101_acq-mprage_run-01_T1w.nii to resized/healthy/resized_sub-A00037318_ses-20130101_acq-mprage_run-01_T1w.nii
# Processing file: nd/healthy/sub-A00037495_ses-20130101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00037495_ses-20130101_acq-mprage_run-02_T1w.nii to resized/healthy/resized_sub-A00037495_ses-20130101_acq-mprage_run-02_T1w.nii
# Processing file: nd/healthy/sub-A00037564_ses-20130101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00037564_ses-20130101_acq-mprage_run-02_T1w.nii to resized/healthy/resized_sub-A00037564_ses-20130101_acq-mprage_run-02_T1w.nii
# Processing file: nd/healthy/sub-A00037665_ses-20130101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00037665_ses-20130101_acq-mprage_run-01_T1w.nii to resized/healthy/resized_sub-A00037665_ses-20130101_acq-mprage_run-01_T1w.nii
# Listing files in directory: nd/schizophrenia/
# Files found: ['sub-01_T1w.nii', 'sub-02_T1w.nii', 'sub-03_T1w.nii', 'sub-04_T1w.nii', 'sub-05_T1w.nii', 'sub-06_T1w.nii', 'sub-07_T1w.nii', 'sub-08_T1w.nii', 'sub-09_T1w.nii', 'sub-100_T1w.nii', 'sub-17_T1w.nii', 'sub-18_T1w.nii', 'sub-19_T1w.nii', 'sub-24_T1w.nii', 'sub-26_T1w.nii', 'sub-27_T1w.nii', 'sub-28_T1w.nii', 'sub-29_T1w.nii', 'sub-30_T1w.nii', 'sub-31_T1w.nii', 'sub-32_T1w.nii', 'sub-33_T1w.nii', 'sub-34_T1w.nii', 'sub-39_T1w.nii', 'sub-40_T1w.nii', 'sub-41_T1w.nii', 'sub-42_T1w.nii', 'sub-44_T1w.nii', 'sub-45_T1w.nii', 'sub-52_T1w.nii', 'sub-60_T1w.nii', 'sub-61_T1w.nii', 'sub-62_T1w.nii', 'sub-63_T1w.nii', 'sub-66_T1w.nii', 'sub-67_T1w.nii', 'sub-68_T1w.nii', 'sub-70_T1w.nii', 'sub-71_T1w.nii', 'sub-74_T1w.nii', 'sub-75_T1w.nii', 'sub-76_T1w.nii', 'sub-77_T1w.nii', 'sub-78_T1w.nii', 'sub-79_T1w.nii', 'sub-80_T1w.nii', 'sub-82_T1w.nii', 'sub-83_T1w.nii', 'sub-84_T1w.nii', 'sub-85_T1w.nii', 'sub-86_T1w.nii', 'sub-91_T1w.nii', 'sub-92_T1w.nii', 'sub-93_T1w.nii', 'sub-94_T1w.nii', 'sub-95_T1w.nii', 'sub-96_T1w.nii', 'sub-99_T1w.nii', 'sub-A00000368_ses-20110101_acq-mprage_run-01_T1w.nii', 'sub-A00000456_ses-20090101_acq-mprage_run-02_T1w.nii', 'sub-A00000541_ses-20100101_acq-mprage_run-02_T1w.nii', 'sub-A00000838_ses-20100101_acq-mprage_run-01_T1w.nii', 'sub-A00000909_ses-20110101_acq-mprage_run-02_T1w.nii', 'sub-A00001181_ses-20100101_acq-mprage_run-02_T1w.nii', 'sub-A00001243_ses-20110101_acq-mprage_run-02_T1w.nii', 'sub-A00001251_ses-20110101_acq-mprage_run-01_T1w.nii', 'sub-A00001452_ses-20100101_acq-mprage_run-02_T1w.nii', 'sub-A00002405_ses-20110101_acq-mprage_run-02_T1w.nii', 'sub-A00002480_ses-20110101_acq-mprage_run-01_T1w.nii', 'sub-A00004507_ses-20120101_acq-mprage_run-02_T1w.nii', 'sub-A00006754_ses-20110101_acq-mprage_run-01_T1w.nii', 'sub-A00009280_ses-20110101_acq-mprage_run-02_T1w.nii', 'sub-A00012767_ses-20100101_acq-mprage_run-01_T1w.nii', 'sub-A00013216_ses-20110101_acq-mprage_run-01_T1w.nii', 'sub-A00014590_ses-20110101_acq-mprage_run-02_T1w.nii', 'sub-A00014607_ses-20100101_acq-mprage_run-01_T1w.nii', 'sub-A00014636_ses-20090101_acq-mprage_run-02_T1w.nii', 'sub-A00014719_ses-20120101_acq-mprage_run-01_T1w.nii', 'sub-A00014804_ses-20090101_acq-mprage_run-01_T1w.nii', 'sub-A00014830_ses-20090101_acq-mprage_run-01_T1w.nii', 'sub-A00015201_ses-20110101_acq-mprage_run-02_T1w.nii', 'sub-A00015518_ses-20100101_acq-mprage_run-02_T1w.nii', 'sub-A00015648_ses-20110101_acq-mprage_run-01_T1w.nii', 'sub-A00016197_ses-20090101_acq-mprage_run-01_T1w.nii', 'sub-A00016720_ses-20110101_acq-mprage_run-02_T1w.nii', 'sub-A00016723_ses-20100101_acq-mprage_run-02_T1w.nii', 'sub-A00017147_ses-20110101_acq-mprage_run-01_T1w.nii', 'sub-A00018129_ses-20100101_acq-mprage_run-01_T1w.nii', 'sub-A00018317_ses-20100101_acq-mprage_run-01_T1w.nii', 'sub-A00018403_ses-20110101_acq-mprage_run-02_T1w.nii', 'sub-A00018434_ses-20100101_acq-mprage_run-02_T1w.nii', 'sub-A00018979_ses-20100101_acq-mprage_run-01_T1w.nii', 'sub-A00019293_ses-20100101_acq-mprage_run-02_T1w.nii', 'sub-A00019349_ses-20100101_acq-mprage_run-01_T1w.nii', 'sub-A00020414_ses-20100101_acq-mprage_run-01_T1w.nii', 'sub-A00020602_ses-20100101_acq-mprage_run-01_T1w.nii', 'sub-A00020787_ses-20100101_acq-mprage_run-02_T1w.nii', 'sub-A00021591_ses-20110101_acq-mprage_run-02_T1w.nii', 'sub-A00021598_ses-20110101_acq-mprage_run-01_T1w.nii', 'sub-A00022500_ses-20100101_acq-mprage_run-01_T1w.nii', 'sub-A00023132_ses-20090101_acq-mprage_run-02_T1w.nii', 'sub-A00023158_ses-20090101_acq-mprage_run-01_T1w.nii', 'sub-A00023243_ses-20090101_acq-mprage_run-01_T1w.nii', 'sub-A00023366_ses-20090101_acq-mprage_run-01_T1w.nii', 'sub-A00023590_ses-20100101_acq-mprage_run-01_T1w.nii', 'sub-A00023750_ses-20090101_acq-mprage_run-01_T1w.nii', 'sub-A00024198_ses-20090101_acq-mprage_run-01_T1w.nii', 'sub-A00024228_ses-20090101_acq-mprage_run-01_T1w.nii', 'sub-A00024568_ses-20090101_acq-mprage_run-01_T1w.nii', 'sub-A00024684_ses-20100101_acq-mprage_run-01_T1w.nii', 'sub-A00024953_ses-20090101_a ...
# Processing file: nd/schizophrenia/sub-01_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-01_T1w.nii to resized/schizophrenia/resized_sub-01_T1w.nii
# Processing file: nd/schizophrenia/sub-02_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-02_T1w.nii to resized/schizophrenia/resized_sub-02_T1w.nii
# Processing file: nd/schizophrenia/sub-03_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-03_T1w.nii to resized/schizophrenia/resized_sub-03_T1w.nii
# Processing file: nd/schizophrenia/sub-04_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-04_T1w.nii to resized/schizophrenia/resized_sub-04_T1w.nii
# Processing file: nd/schizophrenia/sub-05_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-05_T1w.nii to resized/schizophrenia/resized_sub-05_T1w.nii
# Processing file: nd/schizophrenia/sub-06_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-06_T1w.nii to resized/schizophrenia/resized_sub-06_T1w.nii
# Processing file: nd/schizophrenia/sub-07_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-07_T1w.nii to resized/schizophrenia/resized_sub-07_T1w.nii
# Processing file: nd/schizophrenia/sub-08_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-08_T1w.nii to resized/schizophrenia/resized_sub-08_T1w.nii
# Processing file: nd/schizophrenia/sub-09_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-09_T1w.nii to resized/schizophrenia/resized_sub-09_T1w.nii
# Processing file: nd/schizophrenia/sub-100_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-100_T1w.nii to resized/schizophrenia/resized_sub-100_T1w.nii
# Processing file: nd/schizophrenia/sub-17_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-17_T1w.nii to resized/schizophrenia/resized_sub-17_T1w.nii
# Processing file: nd/schizophrenia/sub-18_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-18_T1w.nii to resized/schizophrenia/resized_sub-18_T1w.nii
# Processing file: nd/schizophrenia/sub-19_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-19_T1w.nii to resized/schizophrenia/resized_sub-19_T1w.nii
# Processing file: nd/schizophrenia/sub-24_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-24_T1w.nii to resized/schizophrenia/resized_sub-24_T1w.nii
# Processing file: nd/schizophrenia/sub-26_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-26_T1w.nii to resized/schizophrenia/resized_sub-26_T1w.nii
# Processing file: nd/schizophrenia/sub-27_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-27_T1w.nii to resized/schizophrenia/resized_sub-27_T1w.nii
# Processing file: nd/schizophrenia/sub-28_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-28_T1w.nii to resized/schizophrenia/resized_sub-28_T1w.nii
# Processing file: nd/schizophrenia/sub-29_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-29_T1w.nii to resized/schizophrenia/resized_sub-29_T1w.nii
# Processing file: nd/schizophrenia/sub-30_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-30_T1w.nii to resized/schizophrenia/resized_sub-30_T1w.nii
# Processing file: nd/schizophrenia/sub-31_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-31_T1w.nii to resized/schizophrenia/resized_sub-31_T1w.nii
# Processing file: nd/schizophrenia/sub-32_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-32_T1w.nii to resized/schizophrenia/resized_sub-32_T1w.nii
# Processing file: nd/schizophrenia/sub-33_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-33_T1w.nii to resized/schizophrenia/resized_sub-33_T1w.nii
# Processing file: nd/schizophrenia/sub-34_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-34_T1w.nii to resized/schizophrenia/resized_sub-34_T1w.nii
# Processing file: nd/schizophrenia/sub-39_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-39_T1w.nii to resized/schizophrenia/resized_sub-39_T1w.nii
# Processing file: nd/schizophrenia/sub-40_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-40_T1w.nii to resized/schizophrenia/resized_sub-40_T1w.nii
# Processing file: nd/schizophrenia/sub-41_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-41_T1w.nii to resized/schizophrenia/resized_sub-41_T1w.nii
# Processing file: nd/schizophrenia/sub-42_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-42_T1w.nii to resized/schizophrenia/resized_sub-42_T1w.nii
# Processing file: nd/schizophrenia/sub-44_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-44_T1w.nii to resized/schizophrenia/resized_sub-44_T1w.nii
# Processing file: nd/schizophrenia/sub-45_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-45_T1w.nii to resized/schizophrenia/resized_sub-45_T1w.nii
# Processing file: nd/schizophrenia/sub-52_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-52_T1w.nii to resized/schizophrenia/resized_sub-52_T1w.nii
# Processing file: nd/schizophrenia/sub-60_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-60_T1w.nii to resized/schizophrenia/resized_sub-60_T1w.nii
# Processing file: nd/schizophrenia/sub-61_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-61_T1w.nii to resized/schizophrenia/resized_sub-61_T1w.nii
# Processing file: nd/schizophrenia/sub-62_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-62_T1w.nii to resized/schizophrenia/resized_sub-62_T1w.nii
# Processing file: nd/schizophrenia/sub-63_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-63_T1w.nii to resized/schizophrenia/resized_sub-63_T1w.nii
# Processing file: nd/schizophrenia/sub-66_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-66_T1w.nii to resized/schizophrenia/resized_sub-66_T1w.nii
# Processing file: nd/schizophrenia/sub-67_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-67_T1w.nii to resized/schizophrenia/resized_sub-67_T1w.nii
# Processing file: nd/schizophrenia/sub-68_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-68_T1w.nii to resized/schizophrenia/resized_sub-68_T1w.nii
# Processing file: nd/schizophrenia/sub-70_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-70_T1w.nii to resized/schizophrenia/resized_sub-70_T1w.nii
# Processing file: nd/schizophrenia/sub-71_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-71_T1w.nii to resized/schizophrenia/resized_sub-71_T1w.nii
# Processing file: nd/schizophrenia/sub-74_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-74_T1w.nii to resized/schizophrenia/resized_sub-74_T1w.nii
# Processing file: nd/schizophrenia/sub-75_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-75_T1w.nii to resized/schizophrenia/resized_sub-75_T1w.nii
# Processing file: nd/schizophrenia/sub-76_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-76_T1w.nii to resized/schizophrenia/resized_sub-76_T1w.nii
# Processing file: nd/schizophrenia/sub-77_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-77_T1w.nii to resized/schizophrenia/resized_sub-77_T1w.nii
# Processing file: nd/schizophrenia/sub-78_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-78_T1w.nii to resized/schizophrenia/resized_sub-78_T1w.nii
# Processing file: nd/schizophrenia/sub-79_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-79_T1w.nii to resized/schizophrenia/resized_sub-79_T1w.nii
# Processing file: nd/schizophrenia/sub-80_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-80_T1w.nii to resized/schizophrenia/resized_sub-80_T1w.nii
# Processing file: nd/schizophrenia/sub-82_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-82_T1w.nii to resized/schizophrenia/resized_sub-82_T1w.nii
# Processing file: nd/schizophrenia/sub-83_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-83_T1w.nii to resized/schizophrenia/resized_sub-83_T1w.nii
# Processing file: nd/schizophrenia/sub-84_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-84_T1w.nii to resized/schizophrenia/resized_sub-84_T1w.nii
# Processing file: nd/schizophrenia/sub-85_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-85_T1w.nii to resized/schizophrenia/resized_sub-85_T1w.nii
# Processing file: nd/schizophrenia/sub-86_T1w.nii
# Original data shape: (176, 256, 256)
# Resized and saved sub-86_T1w.nii to resized/schizophrenia/resized_sub-86_T1w.nii
# ...
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00014719_ses-20120101_acq-mprage_run-01_T1w.nii to resized/schizophrenia/resized_sub-A00014719_ses-20120101_acq-mprage_run-01_T1w.nii
# Processing file: nd/schizophrenia/sub-A00014804_ses-20090101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00014804_ses-20090101_acq-mprage_run-01_T1w.nii to resized/schizophrenia/resized_sub-A00014804_ses-20090101_acq-mprage_run-01_T1w.nii
# Processing file: nd/schizophrenia/sub-A00014830_ses-20090101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00014830_ses-20090101_acq-mprage_run-01_T1w.nii to resized/schizophrenia/resized_sub-A00014830_ses-20090101_acq-mprage_run-01_T1w.nii
# Processing file: nd/schizophrenia/sub-A00015201_ses-20110101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00015201_ses-20110101_acq-mprage_run-02_T1w.nii to resized/schizophrenia/resized_sub-A00015201_ses-20110101_acq-mprage_run-02_T1w.nii
# Processing file: nd/schizophrenia/sub-A00015518_ses-20100101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00015518_ses-20100101_acq-mprage_run-02_T1w.nii to resized/schizophrenia/resized_sub-A00015518_ses-20100101_acq-mprage_run-02_T1w.nii
# Processing file: nd/schizophrenia/sub-A00015648_ses-20110101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00015648_ses-20110101_acq-mprage_run-01_T1w.nii to resized/schizophrenia/resized_sub-A00015648_ses-20110101_acq-mprage_run-01_T1w.nii
# Processing file: nd/schizophrenia/sub-A00016197_ses-20090101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00016197_ses-20090101_acq-mprage_run-01_T1w.nii to resized/schizophrenia/resized_sub-A00016197_ses-20090101_acq-mprage_run-01_T1w.nii
# Processing file: nd/schizophrenia/sub-A00016720_ses-20110101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00016720_ses-20110101_acq-mprage_run-02_T1w.nii to resized/schizophrenia/resized_sub-A00016720_ses-20110101_acq-mprage_run-02_T1w.nii
# Processing file: nd/schizophrenia/sub-A00016723_ses-20100101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00016723_ses-20100101_acq-mprage_run-02_T1w.nii to resized/schizophrenia/resized_sub-A00016723_ses-20100101_acq-mprage_run-02_T1w.nii
# Processing file: nd/schizophrenia/sub-A00017147_ses-20110101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00017147_ses-20110101_acq-mprage_run-01_T1w.nii to resized/schizophrenia/resized_sub-A00017147_ses-20110101_acq-mprage_run-01_T1w.nii
# Processing file: nd/schizophrenia/sub-A00018129_ses-20100101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00018129_ses-20100101_acq-mprage_run-01_T1w.nii to resized/schizophrenia/resized_sub-A00018129_ses-20100101_acq-mprage_run-01_T1w.nii
# Processing file: nd/schizophrenia/sub-A00018317_ses-20100101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00018317_ses-20100101_acq-mprage_run-01_T1w.nii to resized/schizophrenia/resized_sub-A00018317_ses-20100101_acq-mprage_run-01_T1w.nii
# Processing file: nd/schizophrenia/sub-A00018403_ses-20110101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00018403_ses-20110101_acq-mprage_run-02_T1w.nii to resized/schizophrenia/resized_sub-A00018403_ses-20110101_acq-mprage_run-02_T1w.nii
# Processing file: nd/schizophrenia/sub-A00018434_ses-20100101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00018434_ses-20100101_acq-mprage_run-02_T1w.nii to resized/schizophrenia/resized_sub-A00018434_ses-20100101_acq-mprage_run-02_T1w.nii
# Processing file: nd/schizophrenia/sub-A00018979_ses-20100101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00018979_ses-20100101_acq-mprage_run-01_T1w.nii to resized/schizophrenia/resized_sub-A00018979_ses-20100101_acq-mprage_run-01_T1w.nii
# Processing file: nd/schizophrenia/sub-A00019293_ses-20100101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00019293_ses-20100101_acq-mprage_run-02_T1w.nii to resized/schizophrenia/resized_sub-A00019293_ses-20100101_acq-mprage_run-02_T1w.nii
# Processing file: nd/schizophrenia/sub-A00019349_ses-20100101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00019349_ses-20100101_acq-mprage_run-01_T1w.nii to resized/schizophrenia/resized_sub-A00019349_ses-20100101_acq-mprage_run-01_T1w.nii
# Processing file: nd/schizophrenia/sub-A00020414_ses-20100101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00020414_ses-20100101_acq-mprage_run-01_T1w.nii to resized/schizophrenia/resized_sub-A00020414_ses-20100101_acq-mprage_run-01_T1w.nii
# Processing file: nd/schizophrenia/sub-A00020602_ses-20100101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00020602_ses-20100101_acq-mprage_run-01_T1w.nii to resized/schizophrenia/resized_sub-A00020602_ses-20100101_acq-mprage_run-01_T1w.nii
# Processing file: nd/schizophrenia/sub-A00020787_ses-20100101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00020787_ses-20100101_acq-mprage_run-02_T1w.nii to resized/schizophrenia/resized_sub-A00020787_ses-20100101_acq-mprage_run-02_T1w.nii
# Processing file: nd/schizophrenia/sub-A00021591_ses-20110101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00021591_ses-20110101_acq-mprage_run-02_T1w.nii to resized/schizophrenia/resized_sub-A00021591_ses-20110101_acq-mprage_run-02_T1w.nii
# Processing file: nd/schizophrenia/sub-A00021598_ses-20110101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00021598_ses-20110101_acq-mprage_run-01_T1w.nii to resized/schizophrenia/resized_sub-A00021598_ses-20110101_acq-mprage_run-01_T1w.nii
# Processing file: nd/schizophrenia/sub-A00022500_ses-20100101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00022500_ses-20100101_acq-mprage_run-01_T1w.nii to resized/schizophrenia/resized_sub-A00022500_ses-20100101_acq-mprage_run-01_T1w.nii
# Processing file: nd/schizophrenia/sub-A00023132_ses-20090101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00023132_ses-20090101_acq-mprage_run-02_T1w.nii to resized/schizophrenia/resized_sub-A00023132_ses-20090101_acq-mprage_run-02_T1w.nii
# Processing file: nd/schizophrenia/sub-A00023158_ses-20090101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00023158_ses-20090101_acq-mprage_run-01_T1w.nii to resized/schizophrenia/resized_sub-A00023158_ses-20090101_acq-mprage_run-01_T1w.nii
# Processing file: nd/schizophrenia/sub-A00023243_ses-20090101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00023243_ses-20090101_acq-mprage_run-01_T1w.nii to resized/schizophrenia/resized_sub-A00023243_ses-20090101_acq-mprage_run-01_T1w.nii
# Processing file: nd/schizophrenia/sub-A00023366_ses-20090101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00023366_ses-20090101_acq-mprage_run-01_T1w.nii to resized/schizophrenia/resized_sub-A00023366_ses-20090101_acq-mprage_run-01_T1w.nii
# Processing file: nd/schizophrenia/sub-A00023590_ses-20100101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00023590_ses-20100101_acq-mprage_run-01_T1w.nii to resized/schizophrenia/resized_sub-A00023590_ses-20100101_acq-mprage_run-01_T1w.nii
# Processing file: nd/schizophrenia/sub-A00023750_ses-20090101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00023750_ses-20090101_acq-mprage_run-01_T1w.nii to resized/schizophrenia/resized_sub-A00023750_ses-20090101_acq-mprage_run-01_T1w.nii
# Processing file: nd/schizophrenia/sub-A00024198_ses-20090101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00024198_ses-20090101_acq-mprage_run-01_T1w.nii to resized/schizophrenia/resized_sub-A00024198_ses-20090101_acq-mprage_run-01_T1w.nii
# Processing file: nd/schizophrenia/sub-A00024228_ses-20090101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00024228_ses-20090101_acq-mprage_run-01_T1w.nii to resized/schizophrenia/resized_sub-A00024228_ses-20090101_acq-mprage_run-01_T1w.nii
# Processing file: nd/schizophrenia/sub-A00024568_ses-20090101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00024568_ses-20090101_acq-mprage_run-01_T1w.nii to resized/schizophrenia/resized_sub-A00024568_ses-20090101_acq-mprage_run-01_T1w.nii
# Processing file: nd/schizophrenia/sub-A00024684_ses-20100101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00024684_ses-20100101_acq-mprage_run-01_T1w.nii to resized/schizophrenia/resized_sub-A00024684_ses-20100101_acq-mprage_run-01_T1w.nii
# Processing file: nd/schizophrenia/sub-A00024953_ses-20090101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00024953_ses-20090101_acq-mprage_run-02_T1w.nii to resized/schizophrenia/resized_sub-A00024953_ses-20090101_acq-mprage_run-02_T1w.nii
# Processing file: nd/schizophrenia/sub-A00027391_ses-20110101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00027391_ses-20110101_acq-mprage_run-01_T1w.nii to resized/schizophrenia/resized_sub-A00027391_ses-20110101_acq-mprage_run-01_T1w.nii
# Processing file: nd/schizophrenia/sub-A00027410_ses-20120101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00027410_ses-20120101_acq-mprage_run-01_T1w.nii to resized/schizophrenia/resized_sub-A00027410_ses-20120101_acq-mprage_run-01_T1w.nii
# Processing file: nd/schizophrenia/sub-A00027537_ses-20110101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00027537_ses-20110101_acq-mprage_run-02_T1w.nii to resized/schizophrenia/resized_sub-A00027537_ses-20110101_acq-mprage_run-02_T1w.nii
# Processing file: nd/schizophrenia/sub-A00027616_ses-20090101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00027616_ses-20090101_acq-mprage_run-01_T1w.nii to resized/schizophrenia/resized_sub-A00027616_ses-20090101_acq-mprage_run-01_T1w.nii
# Processing file: nd/schizophrenia/sub-A00028303_ses-20120101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00028303_ses-20120101_acq-mprage_run-01_T1w.nii to resized/schizophrenia/resized_sub-A00028303_ses-20120101_acq-mprage_run-01_T1w.nii
# Processing file: nd/schizophrenia/sub-A00028404_ses-20110101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00028404_ses-20110101_acq-mprage_run-01_T1w.nii to resized/schizophrenia/resized_sub-A00028404_ses-20110101_acq-mprage_run-01_T1w.nii
# Processing file: nd/schizophrenia/sub-A00028405_ses-20120101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00028405_ses-20120101_acq-mprage_run-02_T1w.nii to resized/schizophrenia/resized_sub-A00028405_ses-20120101_acq-mprage_run-02_T1w.nii
# Processing file: nd/schizophrenia/sub-A00028408_ses-20120101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00028408_ses-20120101_acq-mprage_run-02_T1w.nii to resized/schizophrenia/resized_sub-A00028408_ses-20120101_acq-mprage_run-02_T1w.nii
# Processing file: nd/schizophrenia/sub-A00028410_ses-20120101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00028410_ses-20120101_acq-mprage_run-01_T1w.nii to resized/schizophrenia/resized_sub-A00028410_ses-20120101_acq-mprage_run-01_T1w.nii
# Processing file: nd/schizophrenia/sub-A00028805_ses-20120101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00028805_ses-20120101_acq-mprage_run-01_T1w.nii to resized/schizophrenia/resized_sub-A00028805_ses-20120101_acq-mprage_run-01_T1w.nii
# Processing file: nd/schizophrenia/sub-A00028806_ses-20120101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00028806_ses-20120101_acq-mprage_run-02_T1w.nii to resized/schizophrenia/resized_sub-A00028806_ses-20120101_acq-mprage_run-02_T1w.nii
# Processing file: nd/schizophrenia/sub-A00029486_ses-20120101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00029486_ses-20120101_acq-mprage_run-01_T1w.nii to resized/schizophrenia/resized_sub-A00029486_ses-20120101_acq-mprage_run-01_T1w.nii
# Processing file: nd/schizophrenia/sub-A00031186_ses-20120101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00031186_ses-20120101_acq-mprage_run-02_T1w.nii to resized/schizophrenia/resized_sub-A00031186_ses-20120101_acq-mprage_run-02_T1w.nii
# Processing file: nd/schizophrenia/sub-A00034273_ses-20120101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00034273_ses-20120101_acq-mprage_run-02_T1w.nii to resized/schizophrenia/resized_sub-A00034273_ses-20120101_acq-mprage_run-02_T1w.nii
# Processing file: nd/schizophrenia/sub-A00035003_ses-20120101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00035003_ses-20120101_acq-mprage_run-01_T1w.nii to resized/schizophrenia/resized_sub-A00035003_ses-20120101_acq-mprage_run-01_T1w.nii
# Processing file: nd/schizophrenia/sub-A00035485_ses-20120101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00035485_ses-20120101_acq-mprage_run-01_T1w.nii to resized/schizophrenia/resized_sub-A00035485_ses-20120101_acq-mprage_run-01_T1w.nii
# Processing file: nd/schizophrenia/sub-A00037034_ses-20130101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00037034_ses-20130101_acq-mprage_run-01_T1w.nii to resized/schizophrenia/resized_sub-A00037034_ses-20130101_acq-mprage_run-01_T1w.nii
# Processing file: nd/schizophrenia/sub-A00037224_ses-20130101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00037224_ses-20130101_acq-mprage_run-01_T1w.nii to resized/schizophrenia/resized_sub-A00037224_ses-20130101_acq-mprage_run-01_T1w.nii
# Processing file: nd/schizophrenia/sub-A00037619_ses-20130101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00037619_ses-20130101_acq-mprage_run-02_T1w.nii to resized/schizophrenia/resized_sub-A00037619_ses-20130101_acq-mprage_run-02_T1w.nii
# Processing file: nd/schizophrenia/sub-A00037649_ses-20130101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00037649_ses-20130101_acq-mprage_run-02_T1w.nii to resized/schizophrenia/resized_sub-A00037649_ses-20130101_acq-mprage_run-02_T1w.nii
# Processing file: nd/schizophrenia/sub-A00037854_ses-20130101_acq-mprage_run-02_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00037854_ses-20130101_acq-mprage_run-02_T1w.nii to resized/schizophrenia/resized_sub-A00037854_ses-20130101_acq-mprage_run-02_T1w.nii
# Processing file: nd/schizophrenia/sub-A00038441_ses-20130101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00038441_ses-20130101_acq-mprage_run-01_T1w.nii to resized/schizophrenia/resized_sub-A00038441_ses-20130101_acq-mprage_run-01_T1w.nii
# Processing file: nd/schizophrenia/sub-A00038624_ses-20130101_acq-mprage_run-01_T1w.nii
# Original data shape: (192, 256, 256)
# Resized and saved sub-A00038624_ses-20130101_acq-mprage_run-01_T1w.nii to resized/schizophrenia/resized_sub-A00038624_ses-20130101_acq-mprage_run-01_T1w.nii

# %%
import albumentations as A
import nibabel as nib
import numpy as np
import os
from sklearn.utils import shuffle
from albumentations.pytorch import ToTensorV2

# Directories
he_directory = "resized/healthy/"
sz_directory = "resized/schizophrenia/"

# Augmentation pipeline
def get_augmentation_pipeline():
    return A.Compose([
        A.RandomRotate90(p=0.5),
        A.HorizontalFlip(p=0.5),
        A.VerticalFlip(p=0.5),
        A.RandomBrightnessContrast(brightness_limit=0.2, contrast_limit=0.2, p=0.5),
        A.RandomGamma(gamma_limit=(80, 120), p=0.5),
        A.Resize(height=128, width=128),  # Resize to a common shape if needed
        ToTensorV2()  # Convert to PyTorch tensors if using PyTorch
    ])

def load_images_and_labels(directory, label, augmentation=None):
    files = [f for f in os.listdir(directory) if f.endswith('.nii')]
    images = []
    for file in files:
        file_path = os.path.join(directory, file)
        img = nib.load(file_path)
        data = img.get_fdata()

        # Apply augmentation if provided
        if augmentation:
            for i in range(data.shape[0]):  # Apply augmentation to each slice
                augmented = augmentation(image=data[i])
                images.append(augmented['image'])
        else:
            images.extend(data)

    return np.array(images), np.full(len(images), label)

# Define augmentation pipeline
augmentation_pipeline = get_augmentation_pipeline()

# Load and augment data
S_healthy_images, healthy_labels = load_images_and_labels(he_directory, 0, augmentation=augmentation_pipeline)
S_schiz_images, schiz_labels = load_images_and_labels(sz_directory, 1, augmentation=augmentation_pipeline)

# Concatenate the healthy and diseased data into a single array
S_data = np.concatenate((S_healthy_images, S_schiz_images), axis=0)
S_labels = np.concatenate((healthy_labels, schiz_labels), axis=0)

# Shuffle the data and labels together
S_data, S_labels = shuffle(S_data, S_labels, random_state=42)

# Split the data and labels into training and testing sets
split_index = int(len(S_data) * 0.8)  # 80% for training

S_train_data = S_data[:split_index]
S_test_data = S_data[split_index:]
S_train_labels = S_labels[:split_index]
S_test_labels = S_labels[split_index:]

print(f"Training data shape: {S_train_data.shape}")
print(f"Testing data shape: {S_test_data.shape}")
print(f"Training labels shape: {S_train_labels.shape}")
print(f"Testing labels shape: {S_test_labels.shape}")
# Out:
# Training data shape: (4272, 1, 128, 128)
# Testing data shape: (1068, 1, 128, 128)
# Training labels shape: (4272,)
# Testing labels shape: (1068,)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

def create_3d_cnn_model(input_shape):
    model = models.Sequential()
    model.add(layers.Conv3D(filters=32, kernel_size=(1, 3, 3), activation='relu', input_shape=input_shape))
    model.add(layers.MaxPooling3D(pool_size=(1, 2, 2)))

    model.add(layers.Conv3D(filters=64, kernel_size=(1, 3, 3), activation='relu'))
    model.add(layers.MaxPooling3D(pool_size=(1, 2, 2)))

    model.add(layers.Conv3D(filters=128, kernel_size=(1, 3, 3), activation='relu'))
    model.add(layers.MaxPooling3D(pool_size=(1, 2, 2)))

    model.add(layers.Flatten())
    model.add(layers.Dense(512, activation='relu'))
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(1, activation='sigmoid'))  # Binary classification

    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    return model

input_shape = (1, 128, 128, 1)  # Adjusted for depth of 1
model = create_3d_cnn_model(input_shape)
# Out:
# D:\anaconda\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
from sklearn.utils.class_weight import compute_class_weight

# Compute class weights
class_weights = compute_class_weight('balanced', classes=np.unique(S_train_labels), y=S_train_labels)
class_weight_dict = dict(enumerate(class_weights))

# Compile the model (no class_weight here)
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model with class weights
model.fit(S_train_data, S_train_labels, epochs=100, batch_size=32, class_weight=class_weight_dict)
# Out:
# Epoch 1/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 14s 96ms/step - accuracy: 0.5211 - loss: 10.9425
# Epoch 2/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 13s 95ms/step - accuracy: 0.5833 - loss: 0.6749
# Epoch 3/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 13s 93ms/step - accuracy: 0.5905 - loss: 0.6573
# Epoch 4/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 13s 99ms/step - accuracy: 0.6205 - loss: 0.6431
# Epoch 5/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 13s 94ms/step - accuracy: 0.6325 - loss: 0.6246
# Epoch 6/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 13s 93ms/step - accuracy: 0.6563 - loss: 0.6066
# Epoch 7/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 13s 95ms/step - accuracy: 0.6650 - loss: 0.5752
# Epoch 8/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 13s 97ms/step - accuracy: 0.6769 - loss: 0.5616
# Epoch 9/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 13s 95ms/step - accuracy: 0.6961 - loss: 0.5379
# Epoch 10/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 13s 94ms/step - accuracy: 0.7052 - loss: 0.5370
# Epoch 11/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 13s 94ms/step - accuracy: 0.7165 - loss: 0.5105
# Epoch 12/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 13s 95ms/step - accuracy: 0.7139 - loss: 0.5292
# Epoch 13/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 13s 94ms/step - accuracy: 0.7643 - loss: 0.4623
# Epoch 14/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 13s 94ms/step - accuracy: 0.7466 - loss: 0.4709
# Epoch 15/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 13s 95ms/step - accuracy: 0.7347 - loss: 0.5237
# Epoch 16/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 13s 94ms/step - accuracy: 0.6733 - loss: 0.6153
# Epoch 17/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 13s 94ms/step - accuracy: 0.7309 - loss: 0.4879
# Epoch 18/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 13s 96ms/step - accuracy: 0.7463 - loss: 0.4695
# Epoch 19/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 13s 97ms/step - accuracy: 0.7558 - loss: 0.4689
# Epoch 20/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 13s 97ms/step - accuracy: 0.7597 - loss: 0.4421
# Epoch 21/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 13s 98ms/step - accuracy: 0.7730 - loss: 0.4160
# Epoch 22/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 13s 100ms/step - accuracy: 0.7844 - loss: 0.3945
# Epoch 23/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 13s 96ms/step - accuracy: 0.7914 - loss: 0.3961
# Epoch 24/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 13s 94ms/step - accuracy: 0.8070 - loss: 0.3548
# Epoch 25/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 13s 95ms/step - accuracy: 0.7955 - loss: 0.3879
# Epoch 26/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 13s 98ms/step - accuracy: 0.7828 - loss: 0.3789
# Epoch 27/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 14s 101ms/step - accuracy: 0.7911 - loss: 0.4091
# Epoch 28/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 13s 96ms/step - accuracy: 0.7780 - loss: 0.3887
# Epoch 29/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 13s 96ms/step - accuracy: 0.8112 - loss: 0.3448
# Epoch 30/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 13s 94ms/step - accuracy: 0.8004 - loss: 0.3879
# Epoch 31/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 13s 94ms/step - accuracy: 0.8031 - loss: 0.3638
# Epoch 32/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 13s 94ms/step - accuracy: 0.8220 - loss: 0.3389
# Epoch 33/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 13s 95ms/step - accuracy: 0.8169 - loss: 0.3225
# Epoch 34/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 13s 96ms/step - accuracy: 0.8137 - loss: 0.3544
# Epoch 35/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 13s 94ms/step - accuracy: 0.8158 - loss: 0.3309
# Epoch 36/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 13s 100ms/step - accuracy: 0.8172 - loss: 0.3226
# Epoch 37/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 13s 99ms/step - accuracy: 0.8346 - loss: 0.3061
# Epoch 38/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 13s 98ms/step - accuracy: 0.8261 - loss: 0.3247
# Epoch 39/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 13s 99ms/step - accuracy: 0.8280 - loss: 0.2974
# Epoch 40/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 13s 98ms/step - accuracy: 0.8360 - loss: 0.2857
# Epoch 41/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 13s 93ms/step - accuracy: 0.8168 - loss: 0.3406
# Epoch 42/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 13s 98ms/step - accuracy: 0.8199 - loss: 0.3353
# Epoch 43/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 23s 170ms/step - accuracy: 0.8237 - loss: 0.3525
# Epoch 44/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 23s 170ms/step - accuracy: 0.8391 - loss: 0.3087
# Epoch 45/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 23s 170ms/step - accuracy: 0.8404 - loss: 0.2959
# Epoch 46/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 23s 170ms/step - accuracy: 0.8508 - loss: 0.2805
# Epoch 47/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 23s 170ms/step - accuracy: 0.8410 - loss: 0.2685
# Epoch 48/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 23s 168ms/step - accuracy: 0.8503 - loss: 0.2607
# Epoch 49/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 23s 170ms/step - accuracy: 0.8429 - loss: 0.2569
# Epoch 50/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 23s 169ms/step - accuracy: 0.8498 - loss: 0.2447
# Epoch 51/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 23s 173ms/step - accuracy: 0.8541 - loss: 0.2623
# Epoch 52/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 23s 174ms/step - accuracy: 0.8141 - loss: 0.5203
# Epoch 53/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 15s 115ms/step - accuracy: 0.8357 - loss: 0.2969
# Epoch 54/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 23s 170ms/step - accuracy: 0.8474 - loss: 0.2588
# Epoch 55/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 23s 170ms/step - accuracy: 0.8552 - loss: 0.2488
# Epoch 56/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 23s 169ms/step - accuracy: 0.8520 - loss: 0.2596
# Epoch 57/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 23s 172ms/step - accuracy: 0.8514 - loss: 0.2608
# Epoch 58/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 41s 170ms/step - accuracy: 0.8561 - loss: 0.2466
# Epoch 59/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 24s 176ms/step - accuracy: 0.8523 - loss: 0.3476
# Epoch 60/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 23s 174ms/step - accuracy: 0.8499 - loss: 0.2593
# Epoch 61/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 26s 195ms/step - accuracy: 0.8473 - loss: 0.2734
# Epoch 62/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 64s 363ms/step - accuracy: 0.8501 - loss: 0.2709
# Epoch 63/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 68s 508ms/step - accuracy: 0.8563 - loss: 0.2455
# Epoch 64/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 88s 549ms/step - accuracy: 0.8591 - loss: 0.2328
# Epoch 65/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 60s 378ms/step - accuracy: 0.8495 - loss: 0.2495
# Epoch 66/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 23s 170ms/step - accuracy: 0.8617 - loss: 0.2299
# Epoch 67/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 23s 169ms/step - accuracy: 0.8631 - loss: 0.2382
# Epoch 68/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 23s 169ms/step - accuracy: 0.8580 - loss: 0.2437
# Epoch 69/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 23s 169ms/step - accuracy: 0.8525 - loss: 0.2637
# Epoch 70/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 24s 175ms/step - accuracy: 0.8381 - loss: 0.3942
# Epoch 71/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 23s 173ms/step - accuracy: 0.8534 - loss: 0.2415
# Epoch 72/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 42s 315ms/step - accuracy: 0.8578 - loss: 0.2912
# Epoch 73/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 46s 347ms/step - accuracy: 0.8490 - loss: 0.3117
# Epoch 74/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 23s 170ms/step - accuracy: 0.8660 - loss: 0.2333
# Epoch 75/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 22s 165ms/step - accuracy: 0.8629 - loss: 0.2232
# Epoch 76/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 23s 169ms/step - accuracy: 0.8552 - loss: 0.2293
# Epoch 77/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 23s 172ms/step - accuracy: 0.8592 - loss: 0.2246
# Epoch 78/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 23s 173ms/step - accuracy: 0.8638 - loss: 0.2266
# Epoch 79/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 23s 169ms/step - accuracy: 0.8576 - loss: 0.2527
# Epoch 80/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 23s 169ms/step - accuracy: 0.8411 - loss: 0.3015
# Epoch 81/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 23s 171ms/step - accuracy: 0.8448 - loss: 0.2875
# Epoch 82/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 23s 175ms/step - accuracy: 0.8580 - loss: 0.2479
# Epoch 83/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 21s 155ms/step - accuracy: 0.8574 - loss: 0.2373
# Epoch 84/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 18s 131ms/step - accuracy: 0.8475 - loss: 0.2430
# Epoch 85/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 26s 172ms/step - accuracy: 0.8632 - loss: 0.2270
# Epoch 86/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 23s 172ms/step - accuracy: 0.8616 - loss: 0.2292
# Epoch 87/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 42s 178ms/step - accuracy: 0.8632 - loss: 0.2169
# Epoch 88/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 23s 174ms/step - accuracy: 0.8652 - loss: 0.2232
# Epoch 89/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 24s 176ms/step - accuracy: 0.8554 - loss: 0.2515
# Epoch 90/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 41s 304ms/step - accuracy: 0.8596 - loss: 0.2594
# Epoch 91/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 23s 173ms/step - accuracy: 0.8336 - loss: 0.3075
# Epoch 92/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 23s 172ms/step - accuracy: 0.8531 - loss: 0.2845
# Epoch 93/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 14s 105ms/step - accuracy: 0.8672 - loss: 0.2384
# Epoch 94/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 13s 99ms/step - accuracy: 0.8621 - loss: 0.2275
# Epoch 95/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 13s 96ms/step - accuracy: 0.8565 - loss: 0.2279
# Epoch 96/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 13s 95ms/step - accuracy: 0.8612 - loss: 0.2215
# Epoch 97/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 12s 93ms/step - accuracy: 0.8625 - loss: 0.2253
# Epoch 98/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 12s 92ms/step - accuracy: 0.8545 - loss: 0.2807
# Epoch 99/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 13s 93ms/step - accuracy: 0.8497 - loss: 0.2598
# Epoch 100/100
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 12s 91ms/step - accuracy: 0.8425 - loss: 0.2636

# %%
 #Save the model
model.save('resized/s1.h5')
model.save('resized/s2.keras')

# Load the model (example)
loaded_model_h5 = tf.keras.models.load_model('resized/s1.h5')
loaded_model_keras = tf.keras.models.load_model('resized/s2.keras')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# D:\anaconda\Lib\site-packages\keras\src\saving\saving_lib.py:418: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 12 variables whereas the saved optimizer has 22 variables.
#   trackable.load_own_variables(weights_store.get(inner_path))

# %%
from sklearn.metrics import accuracy_score

# Predict the labels for the test data
S_test_predictions = model.predict(S_test_data)

# Convert predictions to binary class labels if not already done
S_test_predictions_binary = (S_test_predictions > 0.5).astype(int)  # Assuming binary classification

# Calculate accuracy
accuracy = accuracy_score(S_test_labels, S_test_predictions_binary)
print(f"Test Accuracy: {accuracy:.4f}")
# Out:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# Test Accuracy: 0.7228

# %%
from sklearn.metrics import confusion_matrix

# Assuming you have your true labels (S_test_labels) and predictions (S_test_predictions)
S_test_predictions_binary = (S_test_predictions > 0.5).astype(int)  # Convert to binary if needed

# Compute confusion matrix
conf_matrix = confusion_matrix(S_test_labels, S_test_predictions_binary)
print("Confusion Matrix:\n", conf_matrix)
# Out:
# Confusion Matrix:
#  [[430  69]
#  [227 342]]

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, roc_auc_score

# Compute ROC curve
fpr, tpr, thresholds = roc_curve(S_test_labels, S_test_predictions)

# Compute AUC
roc_auc = roc_auc_score(S_test_labels, S_test_predictions)

# Plot ROC curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()

print(f"AUC: {roc_auc:.4f}")
# Out:
# AUC: 0.8072

# %%
from sklearn.metrics import accuracy_score

# Calculate accuracy
accuracy = accuracy_score(S_test_labels, S_test_predictions_binary)
print(f"Accuracy: {accuracy:.4f}")
# Out:
# Accuracy: 0.7228
